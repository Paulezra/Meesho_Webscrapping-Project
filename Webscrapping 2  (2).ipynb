# %%
#pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\ezrap\anaconda3\lib\site-packages (4.22.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\ezrap\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in c:\users\ezrap\anaconda3\lib\site-packages (from selenium) (0.26.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\ezrap\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\ezrap\anaconda3\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\ezrap\anaconda3\lib\site-packages (from selenium) (4.9.0)
# Requirement already satisfied: websocket-client>=1.8.0 in c:\users\ezrap\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\ezrap\anaconda3\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\ezrap\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\ezrap\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\ezrap\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\ezrap\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\ezrap\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\ezrap\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ezrap\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\ezrap\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\ezrap\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests as r

# %%
url = '''https://www.meesho.com/men-watches/pl/3k7'''

print(url)
# Out:
# https://www.meesho.com/men-watches/pl/3k7

# %%
response = r.get(url)

# %%
from selenium import webdriver

loc = r"C:\Users\EZRAP\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"

print(loc)
# Out:
# C:\Users\EZRAP\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe

# %%
cService = webdriver.ChromeService(executable_path=loc)

driver = webdriver.Chrome(service = cService)

driver.get(url)
data = driver.page_source
# data
print('done')
# Out:
# done

# %%
driver.close()

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data,'html.parser')

print('done')
# Out:
# done

# %%
import re
import pandas as pd
from datetime import datetime

all_data = {'watch_name':[],'price':[],'rating':[],'no_of_reviews':[]}

for i in soup.find_all('div',{'class':'sc-ftTHYK bAACl NewProductCardstyled__StyledDetailsCard-sc-6y2tys-1 NewProductCardstyled__StyledDesktopDetailsCard-sc-6y2tys-3 jvYVXh eSUhOk NewProductCardstyled__StyledDetailsCard-sc-6y2tys-1 NewProductCardstyled__StyledDesktopDetailsCard-sc-6y2tys-3 jvYVXh eSUhOk'}):
    
    data = i.text.strip().split('₹')
    if len(data) == 2:
        watch_name,other_details = data
        price, r_r_data = other_details.strip().split(' onwardsFree Delivery')
        rating = r_r_data[:3]
        
        
        review_det = r_r_data[3:].split(' ')
        if len(review_det) == 2:
            all_data['no_of_reviews'].append(review_det[0])
        else:
            all_data['no_of_reviews'].append(0)
            
        all_data['rating'].append(rating)
        all_data['price'].append(price)
        all_data['watch_name'].append(watch_name.strip())
        
    elif len(data) == 3:
        watch_name,price,other_details = data
        all_data['price'].append(price.split(' ')[0])
        all_data['watch_name'].append(watch_name)

        pt = r'\d\.\d'
        result = re.findall(pt,other_details)
        all_data['rating'].append(result[0])
        
        
        
        pt = r'\d\.\d(\d{1,}) Reviews'
        result = re.findall(pt,other_details)
        all_data['no_of_reviews'].append(result[0])

cur_time = datetime.now()
table = pd.DataFrame(all_data)

table['Scrapped_time'] = cur_time

table
# Out:
#                                    watch_name price rating no_of_reviews  \
# 0                          Unique Men Watches   295    3.8           186
# 1                         Stylish Men Watches   148    3.9           931
# 2                          Trendy Men Watches   185    3.6            48
# 3                Men's Elegant Watches Vol 17   358    3.8            77
# 4                  Voguish Men Analog Watches   144    4.0           194
# 5                  Fashionable Analog Watches   231    3.9           218
# 6                Men's Elegant Watches Vol 13   280    4.1           381
# 7                         Stylish Men Watches   149    3.8           436
# 8                       Trendy Sports Watches   186    3.8             0
# 9                          Trendy Men Watches   206    4.0           139
# 10  Colorful Women Analog Watches Men Watches   161    3.6           113
# 11              Attractive Men Analog Watches   230    3.8          1611
# 12                       Colorful Men Watches   374    3.7            13
# 13           Alluring Men Chronograph Watches   148    3.9          1037
# 14                         Trendy Men Watches   145    3.9          1155
# 15                         Unique Men Watches   193    4.1            50
# 16                                    Watches   149    3.6           161
# 17                     Versatile Men  Watches   166    4.1            20
# 18                         Trendy Men Watches   183    4.2            29
# 19                         Unique Men Watches   269    4.3            68
#
#                 Scrapped_time
# 0  2024-08-06 14:56:57.750677
# 1  2024-08-06 14:56:57.750677
# 2  2024-08-06 14:56:57.750677
# 3  2024-08-06 14:56:57.750677
# 4  2024-08-06 14:56:57.750677
# 5  2024-08-06 14:56:57.750677
# 6  2024-08-06 14:56:57.750677
# 7  2024-08-06 14:56:57.750677
# 8  2024-08-06 14:56:57.750677
# 9  2024-08-06 14:56:57.750677
# 10 2024-08-06 14:56:57.750677
# 11 2024-08-06 14:56:57.750677
# 12 2024-08-06 14:56:57.750677
# 13 2024-08-06 14:56:57.750677
# 14 2024-08-06 14:56:57.750677
# 15 2024-08-06 14:56:57.750677
# 16 2024-08-06 14:56:57.750677
# 17 2024-08-06 14:56:57.750677
# 18 2024-08-06 14:56:57.750677
# 19 2024-08-06 14:56:57.750677

# %%
def scrapped_meesho(url):
    import re
    import pandas as pd
    from datetime import datetime
    from selenium import webdriver
    import time
    from bs4 import BeautifulSoup 
    import warnings
    warnings.filterwarnings('ignore')
    # loc = r"C:\Users\EZRAP\Downloads\chromedriver-win64\chromedriver-win64"
    loc = r"C:\Users\EZRAP\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"
    cService  = webdriver.ChromeService(executable_path=loc)

    driver = webdriver.Chrome(service = cService)


    driver.get(url)
    data = driver.page_source
    
    time.sleep(5)
    
    driver.close()
    
    soup = BeautifulSoup(data,'html.parser')
    
    temp_data = url.split('/')
    temp_data.remove('')
    prod_name = temp_data[2]
    
    
    
    all_image = []
    
    for i in soup.find_all('div',{'class':'NewProductCardstyled__ProductImage-sc-6y2tys-18 iWWQS'}):
        for j in i.find_all('img',src=True):
            if '.png' not in j['src']:
    #             print(c,j['src'])
                response = r.get(j['src'])
                bytes_data = response.content
                all_image.append(bytes_data)
#     print(len(all_image))

    all_data = {prod_name:[],'price':[],'rating':[],'no_of_reviews':[],'Images':all_image}
    
    for i in soup.find_all('div',{'class':'sc-ftTHYK bAACl NewProductCardstyled__StyledDetailsCard-sc-6y2tys-1 NewProductCardstyled__StyledDesktopDetailsCard-sc-6y2tys-3 jvYVXh eSUhOk NewProductCardstyled__StyledDetailsCard-sc-6y2tys-1 NewProductCardstyled__StyledDesktopDetailsCard-sc-6y2tys-3 jvYVXh eSUhOk'}):

        data = i.text.strip().split('₹')
        if len(data) == 2:
            watch_name,other_details = data
            price, r_r_data = other_details.strip().split(' onwardsFree Delivery')
            rating = r_r_data[:3]


            review_det = r_r_data[3:].split(' ')
            if len(review_det) == 2:
                all_data['no_of_reviews'].append(review_det[0])
            else:
                all_data['no_of_reviews'].append(0)

            all_data['rating'].append(rating)
            all_data['price'].append(price)
            all_data[prod_name].append(watch_name.strip())

        elif len(data) == 3:
            watch_name,price,other_details = data
            all_data['price'].append(price.split(' ')[0])
            all_data[prod_name].append(watch_name)

            pt = r'\d\.\d'
            result = re.findall(pt,other_details)
            all_data['rating'].append(result[0])



            pt = r'\d\.\d(\d{1,}) Reviews'
            result = re.findall(pt,other_details)
            all_data['no_of_reviews'].append(result[0])

    cur_time = datetime.now()
    table = pd.DataFrame(all_data)
    table['rating'].replace('','0',inplace=True)
    
    table['Scrapped_time'] = cur_time

    return table

# %%
# ------------------------------------

# %%
import requests as r

# %%
url = '''https://www.meesho.com/men-watches/pl/3k7'''

print(url)

# %%
from selenium import webdriver

loc = r"C:\Users\EZRAP\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"

print(loc)
# Out:
# C:\Users\EZRAP\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe

# %%
cService  = webdriver.ChromeService(executable_path=loc)

driver = webdriver.Chrome(service = cService)


driver.get(url)
data = driver.page_source
# data
print('done')

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="671af1d320418ba57270c97cfa8f7ce6")>>

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data,'html.parser')
# soup
print('done')
# Out:
# done

# %%
import re
import pandas as pd
from datetime import datetime

all_data = {'watch_name':[],'price':[],'rating':[],'no_of_reviews':[]}

for i in soup.find_all('div',{'class':'sc-ftTHYK bAACl NewProductCardstyled__StyledDetailsCard-sc-6y2tys-1 NewProductCardstyled__StyledDesktopDetailsCard-sc-6y2tys-3 jvYVXh eSUhOk NewProductCardstyled__StyledDetailsCard-sc-6y2tys-1 NewProductCardstyled__StyledDesktopDetailsCard-sc-6y2tys-3 jvYVXh eSUhOk'}):
    
    data = i.text.strip().split('₹')
    if len(data) == 2:
        watch_name,other_details = data
        price, r_r_data = other_details.strip().split(' onwardsFree Delivery')
        rating = r_r_data[:3]
        
        
        review_det = r_r_data[3:].split(' ')
        if len(review_det) == 2:
            all_data['no_of_reviews'].append(review_det[0])
        else:
            all_data['no_of_reviews'].append(0)

        all_data['rating'].append(rating)
        all_data['price'].append(price)
        all_data['watch_name'].append(watch_name.strip())
        
    elif len(data) == 3:
        watch_name,price,other_details = data
        all_data['price'].append(price.split(' ')[0])
        all_data['watch_name'].append(watch_name)

        pt = r'\d\.\d'
        result = re.findall(pt,other_details)
        all_data['rating'].append(result[0])
        
        
        
        pt = r'\d\.\d(\d{1,}) Reviews'
        result = re.findall(pt,other_details)
        all_data['no_of_reviews'].append(result[0])

cur_time = datetime.now()
table = pd.DataFrame(all_data)

table['Scrapped_time'] = cur_time

table
# Out:
#                                       watch_name price rating no_of_reviews  \
# 0                             Unique Men Watches   295    3.9           180
# 1                            Stylish Men Watches   148    3.9           921
# 2                             Trendy Men Watches   185    3.5            37
# 3                            Stylish Men Watches   149    3.8           433
# 4                             Trendy Men Watches   220    4.0           133
# 5                           Colorful Men Watches   374    3.7            12
# 6      Colorful Women Analog Watches Men Watches   161    3.6           109
# 7                            Classic Men Watches   225    3.9          2426
# 8   DHMT Elite Trendy Men's Analog Watches Vol 1   285    3.9           652
# 9                      Classy Men Analog Watches   151    3.9            76
# 10                            Trendy Men Watches   172    3.6            32
# 11                            Trendy Men Watches   145    3.9          1153
# 12                  Versatile Men Analog Watches   155    3.8            87
# 13                 Free Gift Classic Men Watches   197    4.1           232
# 14     Divine Stylish Analog Men's Watches Vol 8   187    4.0           137
# 15                        Versatile Men  Watches   166    4.1            14
# 16                           Stylish Men Watches   198    4.1            82
# 17                        Attractive Men Watches   253    4.0           126
# 18                            Unique Men Watches   229    4.3            67
# 19                   Alluring Men Analog Watches   204    3.8             9
#
#                 Scrapped_time
# 0  2024-08-01 20:53:57.429951
# 1  2024-08-01 20:53:57.429951
# 2  2024-08-01 20:53:57.429951
# 3  2024-08-01 20:53:57.429951
# 4  2024-08-01 20:53:57.429951
# 5  2024-08-01 20:53:57.429951
# 6  2024-08-01 20:53:57.429951
# 7  2024-08-01 20:53:57.429951
# 8  2024-08-01 20:53:57.429951
# 9  2024-08-01 20:53:57.429951
# 10 2024-08-01 20:53:57.429951
# 11 2024-08-01 20:53:57.429951
# 12 2024-08-01 20:53:57.429951
# 13 2024-08-01 20:53:57.429951
# 14 2024-08-01 20:53:57.429951
# 15 2024-08-01 20:53:57.429951
# 16 2024-08-01 20:53:57.429951
# 17 2024-08-01 20:53:57.429951
# 18 2024-08-01 20:53:57.429951
# 19 2024-08-01 20:53:57.429951

# %%
def scrapped_meesho(url):
    import re
    import pandas as pd
    from datetime import datetime
    from selenium import webdriver
    import time
    from bs4 import BeautifulSoup 
    import warnings
    warnings.filterwarnings('ignore')
        
    loc = r"C:\Users\EZRAP\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"
    
    cService  = webdriver.ChromeService(executable_path=loc)

    driver = webdriver.Chrome(service = cService)


    driver.get(url)
    data = driver.page_source
    
    time.sleep(5)
    
    driver.close()
    
    soup = BeautifulSoup(data,'html.parser')
    
    temp_data = url.split('/')
    temp_data.remove('')
    prod_name = temp_data[2]

    all_image = []
    
    for i in soup.find_all('div',{'class':'NewProductCardstyled__ProductImage-sc-6y2tys-18 iWWQS'}):
        for j in i.find_all('img',src=True):
            if '.png' not in j['src']:
    #             print(c,j['src'])
                response = r.get(j['src'])
                bytes_data = response.content
                all_image.append(bytes_data)
#     print(len(all_image))

    all_data = {prod_name:[],'price':[],'rating':[],'no_of_reviews':[],'Images':all_image}
    
    for i in soup.find_all('div',{'class':'sc-ftTHYK bAACl NewProductCardstyled__StyledDetailsCard-sc-6y2tys-1 NewProductCardstyled__StyledDesktopDetailsCard-sc-6y2tys-3 jvYVXh eSUhOk NewProductCardstyled__StyledDetailsCard-sc-6y2tys-1 NewProductCardstyled__StyledDesktopDetailsCard-sc-6y2tys-3 jvYVXh eSUhOk'}):

        data = i.text.strip().split('₹')
        if len(data) == 2:
            watch_name,other_details = data
            price, r_r_data = other_details.strip().split(' onwardsFree Delivery')
            rating = r_r_data[:3]


            review_det = r_r_data[3:].split(' ')
            if len(review_det) == 2:
                all_data['no_of_reviews'].append(review_det[0])
            else:
                all_data['no_of_reviews'].append(0)

            all_data['rating'].append(rating)
            all_data['price'].append(price)
            all_data[prod_name].append(watch_name.strip())

        elif len(data) == 3:
            watch_name,price,other_details = data
            all_data['price'].append(price.split(' ')[0])
            all_data[prod_name].append(watch_name)

            pt = r'\d\.\d'
            result = re.findall(pt,other_details)
            all_data['rating'].append(result[0])



            pt = r'\d\.\d(\d{1,}) Reviews'
            result = re.findall(pt,other_details)
            all_data['no_of_reviews'].append(result[0])

    cur_time = datetime.now()
    table = pd.DataFrame(all_data)
    table['rating'].replace('','0',inplace=True)
    
    table['Scrapped_time'] = cur_time

    return table

# %%
url = '''https://www.meesho.com/belts-men/pl/3nn'''
# url = '''https://www.meesho.com/jeans-women/pl/3kc'''


all_table = scrapped_meesho(url)

for i in range(1,2):
    url = f'''https://www.meesho.com/belts-men/pl/3nn?page={i}'''
    try:
        all_table = pd.concat([all_table,scrapped_meesho(url)],axis = 0)
        print(f'{i} Page scrapped')
    except Exception as e:
        print(e)
        
all_table
# Out:
# 1 Page scrapped
#                        belts-men price rating no_of_reviews  \
# 0        Styles Latest Men Belts   189    3.3             0
# 1   Fashionable Unique Men Belts   217    3.9         12194
# 2         Fancy Modern Men Belts   165    4.0          1219
# 3        Casual Modern Men Belts   280    4.1            69
# 4        Casual Unique Men Belts   144    3.6          1443
# 5   Fashionable Latest Men Belts   449    3.8             0
# 6        Casual Modern Men Belts   257      0             0
# 7        Casual Modern Men Belts   174    3.9          5138
# 8        Casual Unique Men Belts   135    3.8          2042
# 9        Casual Latest Men Belts   337    3.9             0
# 10       Casual Unique Men Belts   867      0             0
# 11       Styles Trendy Men Belts   160    4.1           336
# 12       Casual Trendy Men Belts   219    3.3             0
# 13  Fashionable Latest Men Belts   189    4.0           607
# 14       Styles Trendy Men Belts   102    3.7         21054
# 15       Styles Latest Men Belts   208    3.3             0
# 16       Casual Modern Men Belts   189    4.1          3035
# 17        Fancy Trendy Men Belts   219    3.0             4
# 18        Fancy Modern Men Belts   177    3.8           280
# 19       Styles Trendy Men Belts   102    3.7         21054
# 0        Styles Latest Men Belts   189    3.3             0
# 1   Fashionable Unique Men Belts   217    3.9         12194
# 2         Fancy Modern Men Belts   165    4.0          1219
# 3        Casual Modern Men Belts   280    4.1            69
# 4        Casual Unique Men Belts   144    3.6          1443
# 5   Fashionable Latest Men Belts   449    3.8             0
# 6        Casual Modern Men Belts   257      0             0
# 7        Casual Modern Men Belts   174    3.9          5138
# 8   Fashionable Latest Men Belts   189    4.0           607
# 9        Casual Latest Men Belts   337    3.9             0
# 10       Casual Unique Men Belts   867      0             0
# 11       Casual Modern Men Belts   189    4.1          3035
# 12       Casual Trendy Men Belts   219    3.3             0
# 13       Casual Unique Men Belts   135    3.8          2042
# 14       Styles Trendy Men Belts   160    4.1           336
# 15       Styles Latest Men Belts   208    3.3             0
# 16       Styles Trendy Men Belts   102    3.7         21054
# 17        Fancy Trendy Men Belts   219    3.0             4
# 18        Fancy Modern Men Belts   177    3.8           280
# 19       Styles Trendy Men Belts   102    3.7         21054
#
#                                                Images  \
# 0   b'RIFF\x90&\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 1   b'RIFFt4\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 2   b'RIFF\x84.\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 3   b'RIFFF%\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 4   b'RIFFdP\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 5   b'RIFFV5\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 6   b'RIFF,\x1a\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 7   b'RIFF\xf6s\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 8   b'RIFF"2\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 9   b'RIFF4*\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 10  b'RIFF\x96;\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 11  b'RIFF\xd8*\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 12  b'RIFF\x00n\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 13  b'RIFF`)\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 14  b'RIFF\x02M\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 15  b'RIFFP\xce\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 16  b'RIFF\xfc-\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 17  b'RIFF\xd6;\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 18  b'RIFF\xd6,\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 19  b'RIFF\x02M\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 0   b'RIFF\x90&\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 1   b'RIFFt4\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 2   b'RIFF\x84.\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 3   b'RIFFF%\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 4   b'RIFFdP\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 5   b'RIFFV5\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 6   b'RIFF,\x1a\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 7   b'RIFF\xf6s\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 8   b'RIFF`)\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 9   b'RIFF4*\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 10  b'RIFF\x96;\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 11  b'RIFF\xfc-\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 12  b'RIFF\x00n\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 13  b'RIFF"2\x00\x00WEBPVP8X\n\x00\x00\x00\x08\x00...
# 14  b'RIFF\xd8*\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 15  b'RIFFP\xce\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 16  b'RIFF\x02M\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 17  b'RIFF\xd6;\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 18  b'RIFF\xd6,\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
# 19  b'RIFF\x02M\x00\x00WEBPVP8X\n\x00\x00\x00\x08\...
#
#                 Scrapped_time
# 0  2024-08-01 20:56:35.178256
# 1  2024-08-01 20:56:35.178256
# 2  2024-08-01 20:56:35.178256
# 3  2024-08-01 20:56:35.178256
# 4  2024-08-01 20:56:35.178256
# 5  2024-08-01 20:56:35.178256
# 6  2024-08-01 20:56:35.178256
# 7  2024-08-01 20:56:35.178256
# 8  2024-08-01 20:56:35.178256
# 9  2024-08-01 20:56:35.178256
# 10 2024-08-01 20:56:35.178256
# 11 2024-08-01 20:56:35.178256
# 12 2024-08-01 20:56:35.178256
# 13 2024-08-01 20:56:35.178256
# 14 2024-08-01 20:56:35.178256
# 15 2024-08-01 20:56:35.178256
# 16 2024-08-01 20:56:35.178256
# 17 2024-08-01 20:56:35.178256
# 18 2024-08-01 20:56:35.178256
# 19 2024-08-01 20:56:35.178256
# 0  2024-08-01 20:57:00.553414
# 1  2024-08-01 20:57:00.553414
# 2  2024-08-01 20:57:00.553414
# 3  2024-08-01 20:57:00.553414
# 4  2024-08-01 20:57:00.553414
# 5  2024-08-01 20:57:00.553414
# 6  2024-08-01 20:57:00.553414
# 7  2024-08-01 20:57:00.553414
# 8  2024-08-01 20:57:00.553414
# 9  2024-08-01 20:57:00.553414
# 10 2024-08-01 20:57:00.553414
# 11 2024-08-01 20:57:00.553414
# 12 2024-08-01 20:57:00.553414
# 13 2024-08-01 20:57:00.553414
# 14 2024-08-01 20:57:00.553414
# 15 2024-08-01 20:57:00.553414
# 16 2024-08-01 20:57:00.553414
# 17 2024-08-01 20:57:00.553414
# 18 2024-08-01 20:57:00.553414
# 19 2024-08-01 20:57:00.553414
